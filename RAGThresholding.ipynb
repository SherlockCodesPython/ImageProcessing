# %%
from matplotlib import pyplot as plt
import skimage
from skimage import data, io,segmentation,color
from skimage import io

img1 = skimage.io.imread(r"C:\Users\Anik Chatterjee\AppData\Local\Programs\Python\Python37-32\Lib\site-packages\skimage\data\coffee.png")
plt.imshow(img1)

#l-mean clustering group togerther pixels as same
# compactness balances color and space 
#segmentation divided in 500
lables_1 = segmentation.slic(img1, compactness = 35, n_segments= 500)
lables_1.shape
segmented_overlay = color.label2rgb(label)
# Out:
# (400, 600)
