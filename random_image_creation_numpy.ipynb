# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import skimage
from skimage import data , io
from skimage.viewer import ImageViewer
from PIL import Image
import numpy as np

from PIL import Image
#image conversion code
im1 = Image.open(r'C:\Users\Anik Chatterjee\AppData\Local\Programs\Python\Python37-32\Lib\site-packages\skimage\data\camera.png')
im1.save(r'C:\Users\Anik Chatterjee\AppData\Local\Programs\Python\Python37-32\Lib\site-packages\skimage\data\camera.jpg')

#print(skimage.__version__)
#%matplotlib inline

sample_image = np.random.random([300, 300])
sample_image.shape
plt.imshow(sample_image)

#plt.imshow(sample_image, cmap= 'gray', interpolation = 'nearest')
#plt.xticks([])
#plt.yticks([])

camera = skimage.io.imread(r"C:\Users\Anik Chatterjee\AppData\Local\Programs\Python\Python37-32\Lib\site-packages\skimage\data\camera.jpg", as_gray=True)
#camera = data.camera()
#plt.figure(figsize=(8,6))
plt.imshow(camera)
camera
#io.imshow(camera)
#plt.show(camera)

#viewer = ImageViewer(camera)
#viewer.show()
# Out:
# array([[156, 157, 158, ..., 151, 151, 151],
#        [159, 158, 157, ..., 152, 152, 152],
#        [161, 159, 157, ..., 154, 154, 154],
#        ...,
#        [121, 123, 127, ..., 123, 113, 107],
#        [121, 122, 123, ..., 123, 116, 112],
#        [120, 124, 127, ..., 121, 116, 115]], dtype=uint8)
